# %% [markdown]
# ### IRIS DATA SET IS FAMILAR DATA SET WHICH IS  USED BY BEGINNERS TO UNDERSTAND THE STANDARDS OF THE DATA ANALYSIS, DATA SCIENCE.

# %%
#importing the libray

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# %%
df=pd.read_csv(r"C:\Users\sirim\Downloads\archive (2)\iris.csv")          #LOAD THE DATASET BY USING DATA FRAME
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### GRAPHICAL REPRESENTATION:-

# %% [markdown]
# #### SCATTER PLOT:- TO FIND THE RELATIONSHIP BETWEEN TWO VARAIBALES

# %%
def relational_graph(df):
    """ relational graph(scatter plot) between pental_length and sepal_length"""
    plt.figure(figsize=(6, 4))
sns.scatterplot(x='petal_length', y='sepal_length', hue='species', data=df)
plt.xlabel('Petal_Length')
plt.ylabel('sepal_length')
plt.title('Petal Length vs. sepal length by Species')
plt.show()

# %%
def categorical_graph(df):
    """categorical graph(box plot) between sepal width and petal width"""
    plt.figure(figsize(4,6))
sns.boxplot(x='species',y='petal_width',data=df)
plt.title("distribution of petal width")
plt.xlabel('species')
plt.ylabel('petal_width')
plt.show()

# %%
def stastical_graph(df):
    """stastical graph(histrogram) of sepal width of species"""
    plt.figure(figsize=(4,6))
sns.histplot(x='sepal_width',hue='species',data=df)
plt.title('distribution of sepal width')
plt.xlabel('sepal_width')
plt.ylabel('frequency')
plt.show()

# %%
def des_data(df):
    """Describes the dataset,which includs  std, min,mean, max, median, skewness, and kurtosis for numerical columns."""
    num_df = df.select_dtypes(include='number')
    
    # descriptive stats
    description = num_df.describe().T  
    description['median'] = num_df.median()  
    description['skewness'] = num_df.apply(skew)  
    description['kurtosis'] = num_df.apply(kurtosis)  
    
    return description
def correlation_matrix(df):
    """the correlation matrix for numeric columns."""
    num_df = df.select_dtypes(include='number')
    correlation_matrix = num_df.corr()
    plt.figure(figsize=(6, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
    plt.title("Correlation Matrix of Iris Dataset")
    plt.show()


iris = sns.load_dataset('iris') 
description = des_data(iris)
print(description)

#correlation matrix
correlation_matrix(iris)
# Out:
#               count      mean       std  min  25%   50%  75%  max  median  \
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9    5.80
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4    3.00
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9    4.35
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5    1.30
#
#               skewness  kurtosis
# sepal_length  0.311753 -0.573568
# sepal_width   0.315767  0.180976
# petal_length -0.272128 -1.395536
# petal_width  -0.101934 -1.336067
